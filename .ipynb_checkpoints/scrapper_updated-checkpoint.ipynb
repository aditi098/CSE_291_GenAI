# %%
import os
import requests
from bs4 import BeautifulSoup

# %%
def get_story_links(main_url):
    response = requests.get(main_url)
    soup = BeautifulSoup(response.content, 'html.parser')
    links = soup.find_all('a')
    story_links = [link.get('href') for link in links if 'author' in link.get('href')]
    return story_links

# %%
def get_story_links_sub(main_url, name):
    response = requests.get(main_url)
    soup = BeautifulSoup(response.content, 'html.parser')
    links = soup.find_all('a')
    story_links = [link.get('href') for link in links if name in link.get('href')]
    return story_links

# %%
def scrape_story(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    paragraphs = soup.find_all('p')  # Assuming the story text is in <p> tags
    story_text = ' '.join(p.get_text().replace('\n', '') for p in paragraphs)
    return story_text

# %%
def scrape_story2(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    paragraphs = soup.find_all('p')  # Assuming the story text is in <p> tags
    story_text = '\n\n\t'.join(p.get_text().strip() for p in paragraphs)
    return story_text

# %%
def scrape_story3(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    paragraphs = soup.find_all('p')  # Assuming the story text is in <p> tags
    story_text = '\\n\\n\\t'.join(p.get_text().strip() for p in paragraphs)
    return story_text

# %%
def save_story_as_text_file(story_name, story_text, file_directory):

    directory_path = f"{file_directory}/{story_name}"
    if not os.path.exists(directory_path):
        os.makedirs(directory_path)

    file_path = f"{directory_path}/story.txt"
    with open(file_path, "w") as file:
        file.write(story_text)

    return file_path

# %%
file_directory = "./dataset"

# %%
# url = 'https://americanliterature.com/childrens-stories/the-three-little-pigs'
# scraped_text = scrape_story(url)
# print(scraped_text)

# %%
main_url = 'https://americanliterature.com/author'
story_links_all = get_story_links(main_url)
story_links_all
# Out:
# ['/author/mother-goose',
#  '/author/rudyard-kipling/book/just-so-stories/summary',
#  '/author/the-brothers-grimm',
#  '/author/aa-milne/book/winnie-the-pooh/summary',
#  '/authors/',
#  '/author-search/',
#  '/author/eleanor-hallowell-abbott',
#  '/author/achmed-abdullah',
#  '/author/andy-adams',
#  '/author/george-ade',
#  '/author/aesop',
#  '/author/anna-akhmatova',
#  '/author/louisa-may-alcott',
#  '/author/thomas-bailey-aldrich',
#  '/author/horatio-alger',
#  '/author/dante',
#  '/author/joseph-a-altsheler',
#  '/author/hans-christian-andersen',
#  '/author/sherwood-anderson',
#  '/author/leonid-andreyev',
#  '/author/maya-angelou',
#  '/author/anonymous',
#  '/author/victor-appleton',
#  '/author/aristotle',
#  '/author/ts-arthur',
#  '/author/peter-christen-asbjornsen',
#  '/author/isaac-asimov',
#  '/author/machado-de-assis',
#  '/author/gertrude-atherton',
#  '/author/margaret-atwood',
#  '/author/wh-auden',
#  '/author/stacy-aumonier',
#  '/author/jane-austen',
#  '/author/li-bai',
#  '/author/james-baldwin',
#  '/author/sullivan-ballou',
#  '/author/honore-de-balzac',
#  '/author/ralph-henry-barbour',
#  '/author/robert-barr',
#  '/author/james-m-barrie',
#  '/author/clara-barton',
#  '/author/matsuo-basho',
#  '/author/frederic-bastiat',
#  '/author/katharine-lee-bates',
#  '/author/l-frank-baum',
#  '/author/rex-ellingwood-beach',
#  '/author/nancy-bell',
#  '/author/edward-bellamy',
#  '/author/francis-bellamy',
#  '/author/arnold-bennett',
#  '/author/ef-benson',
#  '/author/robert-hugh-benson',
#  '/author/jd-beresford',
#  '/author/irving-berlin',
#  '/author/ambrose-bierce',
#  '/author/bjrnstjerne-bjrnson',
#  '/author/r-d-blackmore',
#  '/author/algernon-blackwood',
#  '/author/albert-f-blaisdell',
#  '/author/william-blake',
#  '/author/giovanni-boccaccio',
#  '/author/james-boswell',
#  '/author/ray-bradbury',
#  '/author/loretta-ellen-brady',
#  '/author/vera-brittain',
#  '/author/emily-bronte',
#  '/author/charlotte-bronte',
#  '/author/fredric-brown',
#  '/author/robert-browning',
#  '/author/elizabeth-barrett-browning',
#  '/author/william-cullen-bryant',
#  '/author/pearl-buck',
#  '/author/ivan-bunin',
#  '/author/henry-cuyler-bunner',
#  '/author/john-bunyan',
#  '/author/frances-hodgson-burnett',
#  '/author/robert-burns',
#  '/author/amelia-josephine-burr',
#  '/author/edgar-rice-burroughs',
#  '/author/ellis-parker-butler',
#  '/author/lord-byron',
#  '/author/truman-capote',
#  '/author/lewis-carroll',
#  '/author/guy-wetmore-carryl',
#  '/author/raymond-carver',
#  '/author/willa-cather',
#  '/author/margaret-cavendish',
#  '/author/miguel-de-cervantes',
#  '/author/george-f-chambers',
#  '/author/robert-w-chambers',
#  '/author/geoffrey-chaucer',
#  '/author/anton-chekhov',
#  '/author/charles-w-chesnutt',
#  '/author/gk-chesterton',
#  '/author/gerald-chittenden',
#  '/author/kate-chopin',
#  '/author/agatha-christie',
#  '/author/marcus-clarke',
#  '/author/george-m-cohan',
#  '/author/samuel-taylor-coleridge',
#  '/author/sara-coleridge',
#  '/author/wilkie-collins',
#  '/author/c-collodi',
#  '/author/cornelia-a-p-comer',
#  '/author/confucius',
#  '/author/richard-connell',
#  '/author/joseph-conrad',
#  '/author/grace-macgowan-cooke',
#  '/author/james-fenimore-cooper',
#  '/author/wendy-cope',
#  '/author/stephen-crane',
#  '/author/j-hector-st-john-de-crevoecoeur',
#  '/author/richmal-crompton',
#  '/author/roald-dahl',
#  '/author/richard-harding-davis',
#  '/author/daniel-defoe',
#  '/author/ethel-m-dell',
#  '/author/thomas-de-quincey',
#  '/author/aubrey-thomas-de-vere',
#  '/author/philip-k-dick',
#  '/author/charles-dickens',
#  '/author/emily-dickinson',
#  '/author/william-donahey',
#  '/author/john-donne',
#  '/author/john-dos-passos',
#  '/author/fyodor-dostoevsky',
#  '/author/frederick-douglass',
#  '/author/ernest-dowson',
#  '/author/sir-arthur-conan-doyle',
#  '/author/theodore-dreiser',
#  '/author/web-du-bois',
#  '/author/alexandre-dumas',
#  '/author/alexandre-dumas-fils',
#  '/author/paul-laurence-dunbar',
#  '/author/alice-dunbar-nelson',
#  '/author/walter-a-dyer',
#  '/author/edith-maude-eaton',
#  '/author/johnathan-edwards',
#  '/author/amelia-b-edwards',
#  '/author/ts-eliot',
#  '/author/george-eliot',
#  '/author/ralph-waldo-emerson',
#  '/author/daniel-decatur-emmett',
#  '/author/olaudah-equiano',
#  '/author/evelyn-everett-green',
#  '/author/william-faulkner',
#  '/author/edna-ferber',
#  '/author/parker-fillmore',
#  '/author/dorothy-canfield-fisher',
#  '/author/f-scott-fitzgerald',
#  '/author/edward-fitzgerald',
#  '/author/gustave-flaubert',
#  '/author/mary-hallock-foote',
#  '/author/ford-madox-ford',
#  '/author/em-forster',
#  '/author/george-fox',
#  '/author/benjamin-franklin',
#  '/author/miles-franklin',
#  '/author/mary-e-wilkins-freeman',
#  '/author/r-austin-freeman',
#  '/author/robert-frost',
#  '/author/margaret-fuller',
#  '/author/zona-gale',
#  '/author/john-galsworthy',
#  '/author/ruth-stiles-gannett',
#  '/author/vsevolod-garshin',
#  '/author/elizabeth-gaskell',
#  '/author/swarnakumari-ghosal',
#  '/author/kahlil-gibran',
#  '/author/charlotte-perkins-gilman',
#  '/author/patrick-gilmore',
#  '/author/george-gissing',
#  '/author/susan-glaspell',
#  '/author/nikolai-vasilievich-gogol',
#  '/author/mother-goose',
#  '/author/elizabeth-gordon',
#  '/author/maxim-gorky',
#  '/author/c-houston-alberta-goudiss',
#  '/author/kenneth-grahame',
#  '/author/ulysses-s-grant',
#  '/author/robert-graves',
#  '/author/zane-grey',
#  '/author/the-brothers-grimm',
#  '/author/woody-guthrie',
#  '/author/edward-everett-hale',
#  '/author/william-darcy-haley',
#  '/author/alexander-hamilton',
#  '/author/thomas-hardy',
#  '/author/francis-watkins-harper',
#  '/author/bret-harte',
#  '/author/w-f-harvey',
#  '/author/nathaniel-hawthorne',
#  '/author/lafcadio-hearn',
#  '/author/ernest-hemingway',
#  '/author/o-henry',
#  '/author/oliver-herford',
#  '/author/robert-herrick',
#  '/author/robert-welch-herrick',
#  '/author/hermann-hesse',
#  '/author/violet-moore-higgins',
#  '/author/eta-hoffmann',
#  '/author/mary-jane-holmes',
#  '/author/oliver-wendell-holmes',
#  '/author/homer',
#  '/author/livingston-hopkins',
#  '/author/a-e-housman',
#  '/author/julia-ward-howe',
#  '/author/william-dean-howells',
#  '/author/louis-hughes',
#  '/author/langston-hughes',
#  '/author/victor-hugo',
#  '/author/evan-hunter',
#  '/author/zora-neale-hurston',
#  '/author/aldous-huxley',
#  '/author/henrik-ibsen',
#  '/author/washington-irving',
#  '/author/shirley-jackson',
#  '/author/joseph-jacobs',
#  '/author/w-w-jacobs',
#  '/author/mr-james',
#  '/author/henry-james',
#  '/author/grace-james',
#  '/author/francis-de-haes-janvier',
#  '/author/thomas-jefferson',
#  '/author/jerome-k-jerome',
#  '/author/sarah-orne-jewett',
#  '/author/james-joyce',
#  '/author/franz-kafka',
#  '/author/john-keats',
#  '/author/mrs-ee-kellogg',
#  '/author/jack-kerouac',
#  '/author/francis-scott-key',
#  '/author/alexander-kielland',
#  '/author/joyce-kilmer',
#  '/author/martin-luther-king-jr',
#  '/author/charles-kingsley',
#  '/author/rudyard-kipling',
#  '/author/joseph-martin-kronheim',
#  '/author/aleksandr-i-kuprin',
#  '/author/william-james-lampton',
#  '/author/perceval-landon',
#  '/author/ring-lardner',
#  '/author/wb-laughead',
#  '/author/d-h-lawrence',
#  '/author/henry-lawson',
#  '/author/emma-lazarus',
#  '/author/stephen-leacock',
#  '/author/edward-lear',
#  '/author/harper-lee',
#  '/author/joseph-sheridan-le-fanu',
#  '/author/giacomo-leopardi',
#  '/author/gaston-leroux',
#  '/author/cs-lewis',
#  '/author/sinclair-lewis',
#  '/author/natalie-sumner-lincoln',
#  '/author/john-locke',
#  '/author/hugh-lofting',
#  '/author/jack-london',
#  '/author/julius-long',
#  '/author/henry-wadsworth-longfellow',
#  '/author/henrik-willem-van-loon',
#  '/author/h-p-lovecraft',
#  '/author/james-russell-lowell',
#  '/author/lucretius',
#  '/author/arthur-machen',
#  '/author/niccolo-machiavelli',
#  '/author/james-madison',
#  '/author/katherine-mansfield',
#  '/author/gabriel-garcia-marquez',
#  '/author/george-rr-martin',
#  '/author/william-somerset-maugham',
#  '/author/guy-de-maupassant',
#  '/author/john-mccrae',
#  '/author/walter-mcroberts',
#  '/author/herman-melville',
#  '/author/hl-mencken',
#  '/author/prosper-merimee',
#  '/author/george-henry-miles',
#  '/author/john-stuart-mill',
#  '/author/aa-milne',
#  '/author/john-milton',
#  '/author/jean-baptiste-poquelin-moliere',
#  '/author/lucy-maud-montgomery',
#  '/author/thomas-moore',
#  '/author/wc-morrow',
#  '/author/hh-munro-saki',
#  '/author/vladimir-nabokov',
#  '/author/e-nesbit',
#  '/author/friedrich-nietzsche',
#  '/author/florence-nightingale',
#  '/author/arabian-nights',
#  '/author/frank-norris',
#  '/author/kathleen-norris',
#  '/author/solomon-northup',
#  '/author/caroline-elizabeth-sarah-norton',
#  '/author/fitz-james-obrien',
#  '/author/flannery-oconnor',
#  '/author/liam-oflaherty',
#  '/author/james-okeefe',
#  '/author/eugene-oneill',
#  '/author/george-orwell',
#  '/author/ovid',
#  '/author/wilfred-owen',
#  '/author/thomas-nelson-page',
#  '/author/thomas-paine',
#  '/author/dorothy-parker',
#  '/author/banjo-paterson',
#  '/author/elia-w-peattie',
#  '/author/samuel-pepys',
#  '/author/charles-perrault',
#  '/author/elizabeth-stuart-phelps',
#  '/author/clara-dillingham-pierson',
#  '/author/plato',
#  '/author/edgar-allan-poe',
#  '/author/john-william-polidori',
#  '/author/alexander-pope',
#  '/author/katherine-anne-porter',
#  '/author/melville-davisson-post',
#  '/author/beatrix-potter',
#  '/author/ezra-pound',
#  '/author/marcel-prevost',
#  '/author/alexsander-pushkin',
#  '/author/howard-pyle',
#  '/author/arthur-quiller-couch',
#  '/author/ayn-rand',
#  '/author/laura-e-richards',
#  '/author/katherine-rickford',
#  '/author/james-riley',
#  '/author/james-whitcomb-riley',
#  '/author/mary-roberts-rinehart',
#  '/author/edward-payson-roe',
#  '/author/george-frederick-root',
#  '/author/isaac-rosenberg',
#  '/author/jk-rowling',
#  '/author/bertrand-russell',
#  '/author/arnaba-saha',
#  '/author/jd-salinger',
#  '/author/carl-sandburg',
#  '/author/dorothy-sayers',
#  '/author/sir-walter-scott',
#  '/author/st-semyonov',
#  '/author/anna-sewell',
#  '/author/william-shakespeare',
#  '/author/bernard-shaw',
#  '/author/percy-bysshe-shelley',
#  '/author/mary-shelley',
#  '/author/harold-m-sherman',
#  '/author/mp-shiel',
#  '/author/dora-sigerson-shorter',
#  '/author/upton-sinclair',
#  '/author/adam-smith',
#  '/author/clark-ashton-smith',
#  '/author/samuel-francis-smith',
#  '/author/sophocles',
#  '/author/john-philip-sousa',
#  '/author/thomas-sowell',
#  '/author/harriet-prescott-spofford',
#  '/author/johanna-spyri',
#  '/author/wilbur-daniel-steele',
#  '/author/gertrude-stein',
#  '/author/john-steinbeck',
#  '/author/carl-stephenson',
#  '/author/robert-louis-stevenson',
#  '/author/rl-stine',
#  '/author/frank-stockton',
#  '/author/bram-stoker',
#  '/author/harriet-beecher-stowe',
#  '/author/lytton-strachey',
#  '/author/edward-stratemeyer',
#  '/author/jesse-stuart',
#  '/author/ruth-mcenery-stuart',
#  '/author/edna-st-vincent-millay',
#  '/author/kate-dickinson-sweetser',
#  '/author/jonathan-swift',
#  '/author/netta-syrett',
#  '/author/rabindranath-tagore',
#  '/author/ida-tarbell',
#  '/author/booth-tarkington',
#  '/author/sara-teasdale',
#  '/author/alfred-lord-tennyson',
#  '/author/william-makepeace-thackeray',
#  '/author/ernest-lawrence-thayer',
#  '/author/dylan-thomas',
#  '/author/henry-david-thoreau',
#  '/author/alexis-de-tocqueville',
#  '/author/jrr-tolkien',
#  '/author/leo-tolstoy',
#  '/author/alexei-tolstoy',
#  '/author/pl-travers',
#  '/author/anthony-trollope',
#  '/author/tristram-tupper',
#  '/author/ivan-s-turgenev',
#  '/author/ethel-turner',
#  '/author/mark-twain',
#  '/author/sun-tzu',
#  '/author/henry-van-dyke',
#  '/author/jules-verne',
#  '/author/voltaire',
#  '/author/kurt-vonnegut-jr',
#  '/author/edgar-wallace',
#  '/author/horace-walpole',
#  '/author/booker-t-washington',
#  '/author/weaver-lecron',
#  '/author/ida-b-wells',
#  '/author/hg-wells',
#  '/author/edith-wharton',
#  '/author/anne-hollingsworth-wharton',
#  '/author/phillis-wheatley',
#  '/author/stewart-edward-white',
#  '/author/eb-white',
#  '/author/walt-whitman',
#  '/author/john-greenleaf-whittier',
#  '/author/margaret-widdemer',
#  '/author/kate-douglas-wiggin',
#  '/author/ella-wheeler-wilcox',
#  '/author/oscar-wilde',
#  '/author/margery-williams',
#  '/author/william-carlos-williams',
#  '/author/p-g-wodehouse',
#  '/author/tobias-wolff',
#  '/author/mary-wollstonecraft',
#  '/author/virginia-woolf',
#  '/author/william-wordsworth',
#  '/author/madeline-yale-wynne',
#  '/author/jd-wyss',
#  '/author/william-butler-yeats',
#  '/author/anzia-yezierska',
#  '/author/charlotte-m-yonge',
#  '/author/emile-zola',
#  'https://www.facebook.com/sharer.php?u=https%3A//americanliterature.com/authors/',
#  'https://twitter.com/intent/tweet?text=I+enjoyed+reading&url=https%3A%2F%2Famericanliterature.com%2Fauthors%2F&hashtags=reading,shortstory',
#  'https://reddit.com/submit?url=https%3A//americanliterature.com/authors/']

# %%
# for link in story_links:
#     if link.startswith("aesop/short-story/"):
#         story_name = link.replace('aesop/short-story/', '')
#         story_name = story_name.replace('-', ' ')
#         print(story_name)
#         link = f"https://americanliterature.com/author/{link}/"
#         print(link)
#         pp
#         story_text = scrape_story(link)
#         file_path = save_story_as_text_file(story_name, story_text, file_directory)
#         print(f"Story saved at: {file_path}")
#     else:
#         continue

# %%
# for link in story_links_all:
#     sub_stories_link = []
#     if link.startswith("/author/"):
#         name = link.replace("/author/", '')
#         main_url = f'https://americanliterature.com/author/{name}'
#         sub_story_links = get_story_links_sub(main_url, name)
#         for sub_link in sub_story_links:
#             if sub_link.startswith(f'{name}/'):                
#                 story_name = sub_link.replace(f'{name}/', '')
#                 story_name = story_name.replace('-', ' ')
#                 print(story_name)
#                 sub_link = f"https://americanliterature.com/author/{sub_link}/"
#                 story_text = scrape_story3(sub_link)
#                 file_path = save_story_as_text_file(story_name, story_text, file_directory)
#                 print(f"Story saved at: {file_path}")
#             else:
#                 continue
# Out:
# Story saved at: ./dataset/short story/the naughty boy/story.txt
# short story/the nightingale
# Story saved at: ./dataset/short story/the nightingale/story.txt
# short story/the old bachelors nightcap
# Story saved at: ./dataset/short story/the old bachelors nightcap/story.txt
# short story/the old house
# Story saved at: ./dataset/short story/the old house/story.txt
# short story/the princess and the pea
# Story saved at: ./dataset/short story/the princess and the pea/story.txt
# short story/the real princess
# Story saved at: ./dataset/short story/the real princess/story.txt
# short story/the red shoes
# Story saved at: ./dataset/short story/the red shoes/story.txt
# short story/the saucy boy
# Story saved at: ./dataset/short story/the saucy boy/story.txt
# short story/the shadow
# Story saved at: ./dataset/short story/the shadow/story.txt
# short story/the shirt collar
# Story saved at: ./dataset/short story/the shirt collar/story.txt
# short story/the shoes of fortune
# Story saved at: ./dataset/short story/the shoes of fortune/story.txt
# short story/the snow man
# Story saved at: ./dataset/short story/the snow man/story.txt
# short story/the snow queen
# Story saved at: ./dataset/short story/the snow queen/story.txt
# short story/the story of a mother
# Story saved at: ./dataset/short story/the story of a mother/story.txt
# short story/the story of the wind
# Story saved at: ./dataset/short story/the story of the wind/story.txt
# short story/the story of the year
# Story saved at: ./dataset/short story/the story of the year/story.txt
# short story/the swineherd
# Story saved at: ./dataset/short story/the swineherd/story.txt
# short story/the thorny road of honor
# Story saved at: ./dataset/short story/the thorny road of honor/story.txt
# short story/the tinder box
# Story saved at: ./dataset/short story/the tinder box/story.txt
# short story/the travelling companion
# Story saved at: ./dataset/short story/the travelling companion/story.txt
# short story/the ugly duckling
# Story saved at: ./dataset/short story/the ugly duckling/story.txt
# short story/the wicked prince
# Story saved at: ./dataset/short story/the wicked prince/story.txt
# short story/the wild swans
# Story saved at: ./dataset/short story/the wild swans/story.txt
# short story/the winds tale
# Story saved at: ./dataset/short story/the winds tale/story.txt
# short story/under the willow tree
# Story saved at: ./dataset/short story/under the willow tree/story.txt
# short story/what the moon saw
# Story saved at: ./dataset/short story/what the moon saw/story.txt
# short story/what the old man does is always right
# Story saved at: ./dataset/short story/what the old man does is always right/story.txt
# short story/little tiny or thumbelina
# Story saved at: ./dataset/short story/little tiny or thumbelina/story.txt
# short story/the emperors new clothes
# Story saved at: ./dataset/short story/the emperors new clothes/story.txt
# short story/the little mermaid
# Story saved at: ./dataset/short story/the little mermaid/story.txt
# short story/the princess and the pea
# Story saved at: ./dataset/short story/the princess and the pea/story.txt
# short story/the little match girl
# Story saved at: ./dataset/short story/the little match girl/story.txt
# short story/the little match girl
# Story saved at: ./dataset/short story/the little match girl/story.txt
# short story/the brave tin soldier
# Story saved at: ./dataset/short story/the brave tin soldier/story.txt
# short story/the last dream of old oak
# Story saved at: ./dataset/short story/the last dream of old oak/story.txt
# short story/the shirt collar
# Story saved at: ./dataset/short story/the shirt collar/story.txt
# short story/the goloshes of fortune
# Story saved at: ./dataset/short story/the goloshes of fortune/story.txt
# short story/the saucy boy
# Story saved at: ./dataset/short story/the saucy boy/story.txt
# short story/the old bachelors nightcap
# Story saved at: ./dataset/short story/the old bachelors nightcap/story.txt
# short story/the swineherd
# Story saved at: ./dataset/short story/the swineherd/story.txt
# short story/the travelling companion
# Story saved at: ./dataset/short story/the travelling companion/story.txt
# book/marching men/summary
# Story saved at: ./dataset/book/marching men/summary/story.txt
# book/out of nowhere into nothing/summary
# Story saved at: ./dataset/book/out of nowhere into nothing/summary/story.txt
# book/poor white/summary
# Story saved at: ./dataset/book/poor white/summary/story.txt
# book/windy mcphersons son/summary
# Story saved at: ./dataset/book/windy mcphersons son/summary/story.txt
# book/winesburg ohio/summary
# Story saved at: ./dataset/book/winesburg ohio/summary/story.txt
# short story/an apology for crudity
# Story saved at: ./dataset/short story/an apology for crudity/story.txt
# short story/an awakening
# Story saved at: ./dataset/short story/an awakening/story.txt
# short story/brothers
# Story saved at: ./dataset/short story/brothers/story.txt
# short story/hands
# Story saved at: ./dataset/short story/hands/story.txt
# short story/im a fool
# Story saved at: ./dataset/short story/im a fool/story.txt
# short story/i want to know why
# Story saved at: ./dataset/short story/i want to know why/story.txt
# short story/motherhood
# Story saved at: ./dataset/short story/motherhood/story.txt
# short story/seeds
# Story saved at: ./dataset/short story/seeds/story.txt
# short story/senility
# Story saved at: ./dataset/short story/senility/story.txt
# short story/the door of the trap
# Story saved at: ./dataset/short story/the door of the trap/story.txt
# short story/the dumb man
# Story saved at: ./dataset/short story/the dumb man/story.txt
# short story/the egg
# Story saved at: ./dataset/short story/the egg/story.txt
# short story/the man in the brown coat
# Story saved at: ./dataset/short story/the man in the brown coat/story.txt
# short story/the man with the trumpet
# Story saved at: ./dataset/short story/the man with the trumpet/story.txt
# short story/the new englander
# Story saved at: ./dataset/short story/the new englander/story.txt
# short story/the other woman
# Story saved at: ./dataset/short story/the other woman/story.txt
# short story/unlighted lamps
# Story saved at: ./dataset/short story/unlighted lamps/story.txt
# short story/war
# Story saved at: ./dataset/short story/war/story.txt
# poem/evening song
# Story saved at: ./dataset/poem/evening song/story.txt
# essay/the work of gertrude stein
# Story saved at: ./dataset/essay/the work of gertrude stein/story.txt
# book/winesburg ohio/summary
# Story saved at: ./dataset/book/winesburg ohio/summary/story.txt
# book/winesburg ohio/summary
# Story saved at: ./dataset/book/winesburg ohio/summary/story.txt
# book/winesburg ohio/summary
# Story saved at: ./dataset/book/winesburg ohio/summary/story.txt
# short story/a story which will never be finished
# Story saved at: ./dataset/short story/a story which will never be finished/story.txt
# short story/lazarus
# Story saved at: ./dataset/short story/lazarus/story.txt
# short story/love faith and hope
# Story saved at: ./dataset/short story/love faith and hope/story.txt
# short story/on the day of the crucifixion
# Story saved at: ./dataset/short story/on the day of the crucifixion/story.txt
# short story/the crushed flower
# Story saved at: ./dataset/short story/the crushed flower/story.txt
# short story/the little angel
# Story saved at: ./dataset/short story/the little angel/story.txt
# short story/the red laugh
# Story saved at: ./dataset/short story/the red laugh/story.txt
# short story/the serpents story
# Story saved at: ./dataset/short story/the serpents story/story.txt
# short story/the seven that were hanged
# Story saved at: ./dataset/short story/the seven that were hanged/story.txt
# short story/lazarus
# Story saved at: ./dataset/short story/lazarus/story.txt
# short story/the red laugh
# Story saved at: ./dataset/short story/the red laugh/story.txt
# short story/the seven that were hanged
# Story saved at: ./dataset/short story/the seven that were hanged/story.txt
# short story/lazarus
# Story saved at: ./dataset/short story/lazarus/story.txt
# book/beowulf/summary
# Story saved at: ./dataset/book/beowulf/summary/story.txt
# short story/a little tiny thing
# Story saved at: ./dataset/short story/a little tiny thing/story.txt
# short story/goody two shoes
# Story saved at: ./dataset/short story/goody two shoes/story.txt
# short story/how the moon became beautiful
# Story saved at: ./dataset/short story/how the moon became beautiful/story.txt
# short story/the blind men and the elephant
# Story saved at: ./dataset/short story/the blind men and the elephant/story.txt
# short story/the legend of babouscka
# Story saved at: ./dataset/short story/the legend of babouscka/story.txt
# short story/the little thief in the pantry
# Story saved at: ./dataset/short story/the little thief in the pantry/story.txt
# short story/the night after christmas
# Story saved at: ./dataset/short story/the night after christmas/story.txt
# poem/a christmas hamper
# Story saved at: ./dataset/poem/a christmas hamper/story.txt
# poem/a snow man
# Story saved at: ./dataset/poem/a snow man/story.txt
# poem/halloween
# Story saved at: ./dataset/poem/halloween/story.txt
# poem/jack o lantern song
# Story saved at: ./dataset/poem/jack o lantern song/story.txt
# poem/jolly halloween
# Story saved at: ./dataset/poem/jolly halloween/story.txt
# poem/many thousand gone
# Story saved at: ./dataset/poem/many thousand gone/story.txt
# poem/pumpkins in the cornfield
# Story saved at: ./dataset/poem/pumpkins in the cornfield/story.txt
# poem/taps
# Story saved at: ./dataset/poem/taps/story.txt
# poem/the goblin man
# Story saved at: ./dataset/poem/the goblin man/story.txt
# poem/the soldiers dream of home
# Story saved at: ./dataset/poem/the soldiers dream of home/story.txt
# poem/the true meaning of christmas recited by linus
# Story saved at: ./dataset/poem/the true meaning of christmas recited by linus/story.txt
# poem/winter sport
# Story saved at: ./dataset/poem/winter sport/story.txt
# poem/yankee doodle
# Story saved at: ./dataset/poem/yankee doodle/story.txt
# nursery rhyme/alphabet hand language word posters
# Story saved at: ./dataset/nursery rhyme/alphabet hand language word posters/story.txt
# nursery rhyme/bingo
# Story saved at: ./dataset/nursery rhyme/bingo/story.txt
# nursery rhyme/brahms lullaby
# Story saved at: ./dataset/nursery rhyme/brahms lullaby/story.txt
# nursery rhyme/bye baby bye a lullaby
# Story saved at: ./dataset/nursery rhyme/bye baby bye a lullaby/story.txt
# nursery rhyme/chinese lullaby
# Story saved at: ./dataset/nursery rhyme/chinese lullaby/story.txt
# nursery rhyme/czech lullaby
# Story saved at: ./dataset/nursery rhyme/czech lullaby/story.txt
# nursery rhyme/dutch lullaby
# Story saved at: ./dataset/nursery rhyme/dutch lullaby/story.txt
# nursery rhyme/eeny meeny miny moe
# Story saved at: ./dataset/nursery rhyme/eeny meeny miny moe/story.txt
# nursery rhyme/five little speckled frogs
# Story saved at: ./dataset/nursery rhyme/five little speckled frogs/story.txt
# nursery rhyme/french lullaby
# Story saved at: ./dataset/nursery rhyme/french lullaby/story.txt
# nursery rhyme/goosey goosey gander
# Story saved at: ./dataset/nursery rhyme/goosey goosey gander/story.txt
# nursery rhyme/hink pink riddles
# Story saved at: ./dataset/nursery rhyme/hink pink riddles/story.txt
# nursery rhyme/hinky pinkie riddles
# Story saved at: ./dataset/nursery rhyme/hinky pinkie riddles/story.txt
# nursery rhyme/hush little baby
# Story saved at: ./dataset/nursery rhyme/hush little baby/story.txt
# nursery rhyme/japanese lullaby
# Story saved at: ./dataset/nursery rhyme/japanese lullaby/story.txt
# nursery rhyme/latvian lullaby
# Story saved at: ./dataset/nursery rhyme/latvian lullaby/story.txt
# nursery rhyme/miss mary mack
# Story saved at: ./dataset/nursery rhyme/miss mary mack/story.txt
# nursery rhyme/one potato two potato
# Story saved at: ./dataset/nursery rhyme/one potato two potato/story.txt
# nursery rhyme/one two buckle my shoe
# Story saved at: ./dataset/nursery rhyme/one two buckle my shoe/story.txt
# nursery rhyme/portuguese lullaby
# Story saved at: ./dataset/nursery rhyme/portuguese lullaby/story.txt
# nursery rhyme/ring around the rosie
# Story saved at: ./dataset/nursery rhyme/ring around the rosie/story.txt
# nursery rhyme/scottish lullaby
# Story saved at: ./dataset/nursery rhyme/scottish lullaby/story.txt
# nursery rhyme/spanish lullaby
# Story saved at: ./dataset/nursery rhyme/spanish lullaby/story.txt
# nursery rhyme/star light star bright
# Story saved at: ./dataset/nursery rhyme/star light star bright/story.txt
# nursery rhyme/ten green bottles
# Story saved at: ./dataset/nursery rhyme/ten green bottles/story.txt
# nursery rhyme/the itsy bitsy spider
# Story saved at: ./dataset/nursery rhyme/the itsy bitsy spider/story.txt
# nursery rhyme/this old man
# Story saved at: ./dataset/nursery rhyme/this old man/story.txt
# nursery rhyme/whip poor will lullaby
# Story saved at: ./dataset/nursery rhyme/whip poor will lullaby/story.txt
# christmas carol/all through the night
# Story saved at: ./dataset/christmas carol/all through the night/story.txt
# christmas carol/angels we have heard on high
# Story saved at: ./dataset/christmas carol/angels we have heard on high/story.txt
# christmas carol/away in the manger
# Story saved at: ./dataset/christmas carol/away in the manger/story.txt
# christmas carol/carol of the bells
# Story saved at: ./dataset/christmas carol/carol of the bells/story.txt
# christmas carol/deck the halls
# Story saved at: ./dataset/christmas carol/deck the halls/story.txt
# christmas carol/god rest ye merry gentlemen
# Story saved at: ./dataset/christmas carol/god rest ye merry gentlemen/story.txt
# christmas carol/good king wenceslas
# Story saved at: ./dataset/christmas carol/good king wenceslas/story.txt
# christmas carol/hark the herald angels sing
# Story saved at: ./dataset/christmas carol/hark the herald angels sing/story.txt
# christmas carol/it came upon a midnight clear
# Story saved at: ./dataset/christmas carol/it came upon a midnight clear/story.txt
# christmas carol/jingle bells
# Story saved at: ./dataset/christmas carol/jingle bells/story.txt
# christmas carol/joy to the world
# Story saved at: ./dataset/christmas carol/joy to the world/story.txt
# christmas carol/o christmas tree
# Story saved at: ./dataset/christmas carol/o christmas tree/story.txt
# christmas carol/o come all ye faithful
# Story saved at: ./dataset/christmas carol/o come all ye faithful/story.txt
# christmas carol/o little town of bethlehem
# Story saved at: ./dataset/christmas carol/o little town of bethlehem/story.txt
# christmas carol/silent night
# Story saved at: ./dataset/christmas carol/silent night/story.txt
# christmas carol/the first noel
# Story saved at: ./dataset/christmas carol/the first noel/story.txt
# christmas carol/the twelve days of christmas
# Story saved at: ./dataset/christmas carol/the twelve days of christmas/story.txt
# christmas carol/the wassail song
# Story saved at: ./dataset/christmas carol/the wassail song/story.txt
# christmas carol/we three kings
# Story saved at: ./dataset/christmas carol/we three kings/story.txt
# book/tom swift and his aerial warship/summary
# Story saved at: ./dataset/book/tom swift and his aerial warship/summary/story.txt
# book/tom swift and his airship/summary
# Story saved at: ./dataset/book/tom swift and his airship/summary/story.txt
# book/tom swift and his war tank/summary
# Story saved at: ./dataset/book/tom swift and his war tank/summary/story.txt
# book/politics a treatise on government/summary
# Story saved at: ./dataset/book/politics a treatise on government/summary/story.txt
# book/the poetics of summary
# Story saved at: ./dataset/book/the poetics of summary/story.txt
# book/after the storm/summary
# Story saved at: ./dataset/book/after the storm/summary/story.txt
# short story/a dollar on the conscience
# Story saved at: ./dataset/short story/a dollar on the conscience/story.txt
# short story/after a shadow
# Story saved at: ./dataset/short story/after a shadow/story.txt
# short story/a good name
# Story saved at: ./dataset/short story/a good name/story.txt
# short story/alice and the pigeon
# Story saved at: ./dataset/short story/alice and the pigeon/story.txt
# short story/amys question
# Story saved at: ./dataset/short story/amys question/story.txt
# short story/a mystery explained
# Story saved at: ./dataset/short story/a mystery explained/story.txt
# short story/an angel in disguise
# Story saved at: ./dataset/short story/an angel in disguise/story.txt
# short story/andy lovell
# Story saved at: ./dataset/short story/andy lovell/story.txt
# short story/aunt marys suggestion
# Story saved at: ./dataset/short story/aunt marys suggestion/story.txt
# short story/a visit with the doctor
# Story saved at: ./dataset/short story/a visit with the doctor/story.txt
# short story/both to blame
# Story saved at: ./dataset/short story/both to blame/story.txt
# short story/coffee vs brandy
# Story saved at: ./dataset/short story/coffee vs brandy/story.txt
# short story/common people
# Story saved at: ./dataset/short story/common people/story.txt
# short story/dont mention it
# Story saved at: ./dataset/short story/dont mention it/story.txt
# short story/dressed for a party
# Story saved at: ./dataset/short story/dressed for a party/story.txt
# short story/following the fashions
# Story saved at: ./dataset/short story/following the fashions/story.txt
# short story/going to the springs or vulgar people
# Story saved at: ./dataset/short story/going to the springs or vulgar people/story.txt
# short story/good hearted people
# Story saved at: ./dataset/short story/good hearted people/story.txt
# short story/hadnt time for trouble
# Story saved at: ./dataset/short story/hadnt time for trouble/story.txt
# short story/helping the poor
# Story saved at: ./dataset/short story/helping the poor/story.txt
# short story/in the way of temptation
# Story saved at: ./dataset/short story/in the way of temptation/story.txt
# short story/its none of my business
# Story saved at: ./dataset/short story/its none of my business/story.txt
# short story/little lizzie
# Story saved at: ./dataset/short story/little lizzie/story.txt
# short story/making a sensation
# Story saved at: ./dataset/short story/making a sensation/story.txt
# short story/not at home
# Story saved at: ./dataset/short story/not at home/story.txt
# short story/not great but happy
# Story saved at: ./dataset/short story/not great but happy/story.txt
# short story/on guard
# Story saved at: ./dataset/short story/on guard/story.txt
# short story/other peoples eyes
# Story saved at: ./dataset/short story/other peoples eyes/story.txt
# short story/rights and wrongs
# Story saved at: ./dataset/short story/rights and wrongs/story.txt
# short story/romance and reality
# Story saved at: ./dataset/short story/romance and reality/story.txt
# short story/shadows
# Story saved at: ./dataset/short story/shadows/story.txt
# short story/slow and sure
# Story saved at: ./dataset/short story/slow and sure/story.txt
# short story/something for a cold
# Story saved at: ./dataset/short story/something for a cold/story.txt
# short story/the brilliant and the commonplace
# Story saved at: ./dataset/short story/the brilliant and the commonplace/story.txt
# short story/the fatal error
# Story saved at: ./dataset/short story/the fatal error/story.txt
# short story/the heiress
# Story saved at: ./dataset/short story/the heiress/story.txt
# short story/the humbled pharisee
# Story saved at: ./dataset/short story/the humbled pharisee/story.txt
# short story/the married sisters
# Story saved at: ./dataset/short story/the married sisters/story.txt
# short story/the mothers promise
# Story saved at: ./dataset/short story/the mothers promise/story.txt
# short story/the portrait
# Story saved at: ./dataset/short story/the portrait/story.txt
# short story/the school girl
# Story saved at: ./dataset/short story/the school girl/story.txt
# short story/the thankless office
# Story saved at: ./dataset/short story/the thankless office/story.txt
# short story/the two husbands
# Story saved at: ./dataset/short story/the two husbands/story.txt
# short story/the wife
# Story saved at: ./dataset/short story/the wife/story.txt
# short story/unredeemed pledges
# Story saved at: ./dataset/short story/unredeemed pledges/story.txt
# short story/very poor
# Story saved at: ./dataset/short story/very poor/story.txt
# short story/visiting as neighbors
# Story saved at: ./dataset/short story/visiting as neighbors/story.txt
# short story/what can i do
# Story saved at: ./dataset/short story/what can i do/story.txt
# short story/which was most the lady
# Story saved at: ./dataset/short story/which was most the lady/story.txt
# short story/grumblegizzard
# Story saved at: ./dataset/short story/grumblegizzard/story.txt
# short story/round the yule log christmas in norway
# Story saved at: ./dataset/short story/round the yule log christmas in norway/story.txt
# fairy tale/east of the sun and west of the moon
# Story saved at: ./dataset/fairy tale/east of the sun and west of the moon/story.txt
# fairy tale/the giant who had no heart in his body
# Story saved at: ./dataset/fairy tale/the giant who had no heart in his body/story.txt
# fairy tale/the lad who went to the north wind
# Story saved at: ./dataset/fairy tale/the lad who went to the north wind/story.txt
# short story/round the yule log christmas in norway
# Story saved at: ./dataset/short story/round the yule log christmas in norway/story.txt
# book/youth/summary
# Story saved at: ./dataset/book/youth/summary/story.txt
# book/dom casmurro/summary
# Story saved at: ./dataset/book/dom casmurro/summary/story.txt
# short story/life
# Story saved at: ./dataset/short story/life/story.txt
# short story/the attendants confession
# Story saved at: ./dataset/short story/the attendants confession/story.txt
# short story/the fortune teller
# Story saved at: ./dataset/short story/the fortune teller/story.txt
# short story/death and the woman
# Story saved at: ./dataset/short story/death and the woman/story.txt
# short story/the bell in the fog
# Story saved at: ./dataset/short story/the bell in the fog/story.txt
# short story/the sacrificial alter
# Story saved at: ./dataset/short story/the sacrificial alter/story.txt
# short story/the striding place
# Story saved at: ./dataset/short story/the striding place/story.txt
# essay/the conqueror
# Story saved at: ./dataset/essay/the conqueror/story.txt
# short story/the striding place
# Story saved at: ./dataset/short story/the striding place/story.txt
# poem/the more loving one
# Story saved at: ./dataset/poem/the more loving one/story.txt
# poem/the more loving one
# Story saved at: ./dataset/poem/the more loving one/story.txt
# short story/a source of irritation
# Story saved at: ./dataset/short story/a source of irritation/story.txt
# short story/where was wych street
# Story saved at: ./dataset/short story/where was wych street/story.txt
# short story/where was wych street
# Story saved at: ./dataset/short story/where was wych street/story.txt
# book/emma/summary
# Story saved at: ./dataset/book/emma/summary/story.txt
# book/lady susan/summary
# Story saved at: ./dataset/book/lady susan/summary/story.txt
# book/mansfield park/summary
# Story saved at: ./dataset/book/mansfield park/summary/story.txt
# book/northanger abbey/summary
# Story saved at: ./dataset/book/northanger abbey/summary/story.txt
# book/persuasion/summary
# Story saved at: ./dataset/book/persuasion/summary/story.txt
# book/pride and prejudice/summary
# Story saved at: ./dataset/book/pride and prejudice/summary/story.txt
# book/sense and sensibility/summary
# Story saved at: ./dataset/book/sense and sensibility/summary/story.txt
# book/the watsons/summary
# Story saved at: ./dataset/book/the watsons/summary/story.txt
# book/sense and sensibility/summary
# Story saved at: ./dataset/book/sense and sensibility/summary/story.txt
# book/pride and prejudice/summary
# Story saved at: ./dataset/book/pride and prejudice/summary/story.txt
# book/mansfield park/summary
# Story saved at: ./dataset/book/mansfield park/summary/story.txt
# book/emma/summary
# Story saved at: ./dataset/book/emma/summary/story.txt
# poem/about du fu
# Story saved at: ./dataset/poem/about du fu/story.txt
# poem/a farewell to secretary shuyun at the xietiao villa in xuanzhou
# Story saved at: ./dataset/poem/a farewell to secretary shuyun at the xietiao villa in xuanzhou/story.txt
# poem/alone and drinking under the moon
# Story saved at: ./dataset/poem/alone and drinking under the moon/story.txt
# poem/alone looking at the mountain
# Story saved at: ./dataset/poem/alone looking at the mountain/story.txt
# poem/amidst the flowers a jug of wine
# Story saved at: ./dataset/poem/amidst the flowers a jug of wine/story.txt
# poem/a mountain revelry
# Story saved at: ./dataset/poem/a mountain revelry/story.txt
# poem/a poem of changgan
# Story saved at: ./dataset/poem/a poem of changgan/story.txt
# poem/a song of an autumn midnight
# Story saved at: ./dataset/poem/a song of an autumn midnight/story.txt
# poem/autumn river song
# Story saved at: ./dataset/poem/autumn river song/story.txt
# poem/a vindication
# Story saved at: ./dataset/poem/a vindication/story.txt
# poem/ballads of four seasons spring
# Story saved at: ./dataset/poem/ballads of four seasons spring/story.txt
# poem/ballads of four seasons summer
# Story saved at: ./dataset/poem/ballads of four seasons summer/story.txt
# poem/ballads of four seasons winter
# Story saved at: ./dataset/poem/ballads of four seasons winter/story.txt
# poem/bathed and washed
# Story saved at: ./dataset/poem/bathed and washed/story.txt
# poem/before the cask of wine
# Story saved at: ./dataset/poem/before the cask of wine/story.txt
# poem/bringing in the wine
# Story saved at: ./dataset/poem/bringing in the wine/story.txt
# poem/chiang chin chiu
# Story saved at: ./dataset/poem/chiang chin chiu/story.txt
# poem/ching ping tiao
# Story saved at: ./dataset/poem/ching ping tiao/story.txt
# poem/chuang tzu and the butterfly
# Story saved at: ./dataset/poem/chuang tzu and the butterfly/story.txt
# poem/clearing at dawn
# Story saved at: ./dataset/poem/clearing at dawn/story.txt
# poem/climbing west of lotus flower peak
# Story saved at: ./dataset/poem/climbing west of lotus flower peak/story.txt
# poem/confessional
# Story saved at: ./dataset/poem/confessional/story.txt
# poem/down from the mountain
# Story saved at: ./dataset/poem/down from the mountain/story.txt
# poem/down zhongnan mountain
# Story saved at: ./dataset/poem/down zhongnan mountain/story.txt
# poem/drinking alone
# Story saved at: ./dataset/poem/drinking alone/story.txt
# poem/drinking alone in the moonlight
# Story saved at: ./dataset/poem/drinking alone in the moonlight/story.txt
# poem/drinking in the mountains
# Story saved at: ./dataset/poem/drinking in the mountains/story.txt
# poem/drinking with someone in the mountains
# Story saved at: ./dataset/poem/drinking with someone in the mountains/story.txt
# poem/exiles letter bai
# Story saved at: ./dataset/poem/exiles letter bai/story.txt
# poem/farewell to meng hao jan
# Story saved at: ./dataset/poem/farewell to meng hao jan/story.txt
# poem/farewell to secretary shu yun at the hsieh tiao villa in hsuan chou
# Story saved at: ./dataset/poem/farewell to secretary shu yun at the hsieh tiao villa in hsuan chou/story.txt
# poem/for meng hao jan
# Story saved at: ./dataset/poem/for meng hao jan/story.txt
# poem/gazing at the cascade on lu mountain
# Story saved at: ./dataset/poem/gazing at the cascade on lu mountain/story.txt
# poem/going up yoyang tower
# Story saved at: ./dataset/poem/going up yoyang tower/story.txt
# poem/gold painted jars wines worth a thousand
# Story saved at: ./dataset/poem/gold painted jars wines worth a thousand/story.txt
# poem/good old moon
# Story saved at: ./dataset/poem/good old moon/story.txt
# poem/green mountain
# Story saved at: ./dataset/poem/green mountain/story.txt
# poem/hard is the journey
# Story saved at: ./dataset/poem/hard is the journey/story.txt
# poem/his dream of the skyland
# Story saved at: ./dataset/poem/his dream of the skyland/story.txt
# poem/ho chih chang
# Story saved at: ./dataset/poem/ho chih chang/story.txt
# poem/in spring
# Story saved at: ./dataset/poem/in spring/story.txt
# poem/lament for mr tai
# Story saved at: ./dataset/poem/lament for mr tai/story.txt
# poem/lament of the frontier guard
# Story saved at: ./dataset/poem/lament of the frontier guard/story.txt
# poem/leaving white king city
# Story saved at: ./dataset/poem/leaving white king city/story.txt
# poem/lines for a taoist adept
# Story saved at: ./dataset/poem/lines for a taoist adept/story.txt
# poem/listening to a flute in yellow crane pavillion
# Story saved at: ./dataset/poem/listening to a flute in yellow crane pavillion/story.txt
# poem/long yearning sent far
# Story saved at: ./dataset/poem/long yearning sent far/story.txt
# poem/looking for a monk and not finding him
# Story saved at: ./dataset/poem/looking for a monk and not finding him/story.txt
# poem/lu mountain kiangsi
# Story saved at: ./dataset/poem/lu mountain kiangsi/story.txt
# poem/marble stairs grievance
# Story saved at: ./dataset/poem/marble stairs grievance/story.txt
# poem/moon over mountain pass
# Story saved at: ./dataset/poem/moon over mountain pass/story.txt
# poem/mountain drinking song
# Story saved at: ./dataset/poem/mountain drinking song/story.txt
# poem/nefarious war
# Story saved at: ./dataset/poem/nefarious war/story.txt
# poem/old poem
# Story saved at: ./dataset/poem/old poem/story.txt
# poem/on a picture screen
# Story saved at: ./dataset/poem/on a picture screen/story.txt
# poem/on climbing in nan king to the terrace of phoenixes
# Story saved at: ./dataset/poem/on climbing in nan king to the terrace of phoenixes/story.txt
# poem/on dragon hill
# Story saved at: ./dataset/poem/on dragon hill/story.txt
# poem/on kusu terrace
# Story saved at: ./dataset/poem/on kusu terrace/story.txt
# poem/parting at a wine shop in nan king
# Story saved at: ./dataset/poem/parting at a wine shop in nan king/story.txt
# poem/quiet night thoughts
# Story saved at: ./dataset/poem/quiet night thoughts/story.txt
# poem/reaching the hermitage
# Story saved at: ./dataset/poem/reaching the hermitage/story.txt
# poem/remembering the springs at chaih chou
# Story saved at: ./dataset/poem/remembering the springs at chaih chou/story.txt
# poem/resentment near the jade stairs
# Story saved at: ./dataset/poem/resentment near the jade stairs/story.txt
# poem/self abandonment
# Story saved at: ./dataset/poem/self abandonment/story.txt
# poem/she spins silk
# Story saved at: ./dataset/poem/she spins silk/story.txt
# poem/song of the forge
# Story saved at: ./dataset/poem/song of the forge/story.txt
# poem/song of the jade cup
# Story saved at: ./dataset/poem/song of the jade cup/story.txt
# poem/spring night in lo yang hearing a flute
# Story saved at: ./dataset/poem/spring night in lo yang hearing a flute/story.txt
# poem/summer in the mountains
# Story saved at: ./dataset/poem/summer in the mountains/story.txt
# poem/taking leave of a friend
# Story saved at: ./dataset/poem/taking leave of a friend/story.txt
# poem/the cold clear spring at nanyang
# Story saved at: ./dataset/poem/the cold clear spring at nanyang/story.txt
# poem/the exiles letter
# Story saved at: ./dataset/poem/the exiles letter/story.txt
# poem/the moon at the fortified pass
# Story saved at: ./dataset/poem/the moon at the fortified pass/story.txt
# poem/the old dust
# Story saved at: ./dataset/poem/the old dust/story.txt
# poem/the river captains wife a letter
# Story saved at: ./dataset/poem/the river captains wife a letter/story.txt
# poem/the river merchants wife
# Story saved at: ./dataset/poem/the river merchants wife/story.txt
# poem/the roosting crows
# Story saved at: ./dataset/poem/the roosting crows/story.txt
# poem/thoughts in a tranquil night
# Story saved at: ./dataset/poem/thoughts in a tranquil night/story.txt
# poem/three with the moon and his shadow
# Story saved at: ./dataset/poem/three with the moon and his shadow/story.txt
# poem/through the yangzi gorges
# Story saved at: ./dataset/poem/through the yangzi gorges/story.txt
# poem/to his two children
# Story saved at: ./dataset/poem/to his two children/story.txt
# poem/to my wife on lu shan mountain
# Story saved at: ./dataset/poem/to my wife on lu shan mountain/story.txt
# poem/to tan chiu
# Story saved at: ./dataset/poem/to tan chiu/story.txt
# poem/to tu fu from shantung
# Story saved at: ./dataset/poem/to tu fu from shantung/story.txt
# poem/to wang lun
# Story saved at: ./dataset/poem/to wang lun/story.txt
# poem/under the moon
# Story saved at: ./dataset/poem/under the moon/story.txt
# poem/visiting a taoist on tiatien mountain
# Story saved at: ./dataset/poem/visiting a taoist on tiatien mountain/story.txt
# poem/waking from drunken sleep on a spring day
# Story saved at: ./dataset/poem/waking from drunken sleep on a spring day/story.txt
# poem/waterfall at lu shan
# Story saved at: ./dataset/poem/waterfall at lu shan/story.txt
# poem/we fought for south of the walls
# Story saved at: ./dataset/poem/we fought for south of the walls/story.txt
# poem/wine
# Story saved at: ./dataset/poem/wine/story.txt
# poem/yearning
# Story saved at: ./dataset/poem/yearning/story.txt
# poem/ziyi song
# Story saved at: ./dataset/poem/ziyi song/story.txt
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[81], line 6
#       4 name = link.replace("/author/", '')
#       5 main_url = f'https://americanliterature.com/author/{name}'
# ----> 6 sub_story_links = get_story_links_sub(main_url, name)
#       7 for sub_link in sub_story_links:
#       8     if sub_link.startswith(f'{name}/'):
#
# Cell In[73], line 5, in get_story_links_sub(main_url, name)
#       3 soup = BeautifulSoup(response.content, 'html.parser')
#       4 links = soup.find_all('a')
# ----> 5 story_links = [link.get('href') for link in links if name in link.get('href')]
#       6 return story_links
#
# Cell In[73], line 5, in <listcomp>(.0)
#       3 soup = BeautifulSoup(response.content, 'html.parser')
#       4 links = soup.find_all('a')
# ----> 5 story_links = [link.get('href') for link in links if name in link.get('href')]
#       6 return story_links
#
# TypeError: argument of type 'NoneType' is not iterable

# %%
# import os
# import re  # Import the regular expressions module

# # Clean fairy tales dataset
# base_path = "./dataset/fairy tale"
# for folder in os.listdir(base_path):
#     if not folder.startswith('.DS_Store'):
#         with open(os.path.join(base_path, folder, 'story.txt'), 'r') as file:
#             file_contents = file.read()

#         # Replace line breaks with spaces
#         file_contents = file_contents.replace('\n', ' ')

#         # Replace " with '
#         story_text = file_contents.replace('"', "'")

#         # Find the positions of fixed markers
#         marker_position2 = story_text.find("Return to the The")
#         marker_position3 = story_text.rfind("\n\n\t\n\n\t\n\n\t\n\n\t")

#         # Find the position of the variable marker using regex for "Add .*? to your library"
#         regex_pattern_add = r'Add .*? to your library'
#         regex_match_add = re.search(regex_pattern_add, story_text)
#         marker_position1 = regex_match_add.start() if regex_match_add else -1

#         # Find the last position of "\n\n\t" and remove it along with following text
#         marker_position4 = story_text.rfind("\n\n\t")

#         # Find the position of the variable marker using regex for "<> was featured as <>"
#         regex_pattern_featured = r'.*? was featured as .*'
#         regex_match_featured = re.search(regex_pattern_featured, story_text)
#         marker_position5 = regex_match_featured.start() if regex_match_featured else -1

#         # Remove numbers at the end of the text
#         story_text = re.sub(r'\s*\d+\.?\d*\s*$', '', story_text)

#         # Create a list of valid positions (excluding -1)
#         valid_positions = [pos for pos in [marker_position1, marker_position2, marker_position3, marker_position4, marker_position5] if pos != -1]
        
#         # If any valid position is found, trim the content from the earliest marker
#         if valid_positions:
#             marker_position = min(valid_positions)
#             story_text = story_text[:marker_position]

#         # Create the output directory and write the cleaned text to a new file
#         new_folder = os.path.join("./clean_dataset/fairy_tale", folder)
#         os.makedirs(new_folder, exist_ok=True)
#         new_file_path = os.path.join(new_folder, 'story.txt')
        
#         with open(new_file_path, 'w') as new_file:
#             new_file.write(story_text)

# %%
import os
import re  # Import the regular expressions module
count = 0
# Clean short story dataset
base_path = "./dataset/short story"
for folder in os.listdir(base_path):
    # print(folder)
    if not folder.startswith('.DS_Store'):
        if folder == "the lion and the gnat":
            print("yes")
            with open(os.path.join(base_path, folder, 'story.txt'), 'r') as file:
                file_contents = file.read()
    
            # Replace line breaks with spaces
            file_contents = file_contents.replace('\n', ' ')
    
            # Replace " with '
            story_text = file_contents.replace('"', "'")
    
            # Find the positions of fixed markers
            marker_position1 = story_text.find("Add  A")
            marker_position2 = story_text.find("Read the next short story")
            marker_position3 = story_text.find("Return to the")
            marker_position4 = story_text.rfind("\n\n\t\n\n\t\n\n\t\n\n\t")
            marker_position5 = story_text.rfind("\n\n\t")
    
            # Find the position of the variable marker using regex for "<> was featured as <>"
            regex_pattern = r'.*? was featured as .*'
            regex_match = re.search(regex_pattern, story_text)
            marker_position6 = regex_match.start() if regex_match else -1
    
            # Remove numbers at the end of the text
            story_text = re.sub(r'\s*\d+\.?\d*\s*$', '', story_text)
    
            # Create a list of valid positions (excluding -1)
            valid_positions = [pos for pos in [marker_position1, marker_position2, marker_position3, marker_position4, marker_position5, marker_position6] if pos != -1]
            
            # If any valid position is found, trim the content from the earliest marker
            if valid_positions:
                marker_position = min(valid_positions)
                story_text = story_text[:marker_position]
    
            # Create the output directory and write the cleaned text to a new file
            new_folder = os.path.join("./clean_dataset/short_story", folder)
            os.makedirs(new_folder, exist_ok=True)
            new_file_path = os.path.join(new_folder, 'story.txt')
            
            with open(new_file_path, 'w') as new_file:
                new_file.write(story_text)
# Out:
# senility
# 1
# rights and wrongs
# 2
# belling the cat
# 3
# the fox and the hedgehog
# 4
# the cat and the birds
# 5
# the brave tin soldier
# 6
# the beetle who went on his travels
# 7
# a question of possession
# 8
# kittys class day
# 9
# the boy and the filberts
# 10
# the wife
# 11
# the eagle and the kite
# 12
# the lark and her young ones
# 13
# mercury and the woodman
# 14
# the travelling companion
# 15
# the candy country
# 16
# drifting north
# 17
# the frogs and the well
# 18
# the rabbit the weasel and the cat
# 19
# lost in a london fog
# 20
# the cruise of the dolphin
# 21
# after a shadow
# 22
# the farmer and the snake
# 23
# what the moon saw
# 24
# an apology for crudity
# 25
# the crow and the pitcher
# 26
# im a fool
# 27
# the ass and its shadow
# 28
# a raven and a swan
# 29
# strength of the little thin thread
# 30
# the man with the trumpet
# 31
# the blind men and the elephant
# 32
# good hearted people
# 33
# the farmer and the stork
# 34
# the heiress
# 35
# the wolf and the goat
# 36
# not great but happy
# 37
# the ass and the grasshoppers
# 38
# the goloshes of fortune
# 39
# not at home
# 40
# helping the poor
# 41
# the birds the beasts and the bat
# 42
# amys question
# 43
# the brilliant and the commonplace
# 44
# the crushed flower
# 45
# the farmer and the cranes
# 46
# an indian jataka
# 47
# a dollar on the conscience
# 48
# the bell
# 49
# the little thief in the pantry
# 50
# the emperors new clothes
# 51
# the pack ass and the wild ass
# 52
# the marsh kings daughter
# 53
# .DS_Store
# 54
# little tiny or thumbelina
# 55
# the wolf the kid and the goat
# 56
# the story of the year
# 57
# the ass and his driver
# 58
# the swineherd
# 59
# the miller his son and the ass
# 60
# the lion and the gnat
# yes
# 61
# the boy and the nettle
# 62
# a whisper in the dark
# 63
# the leap frog
# 64
# two travelers and a bear
# 65
# the ant and the dove
# 66
# the stag the sheep and the wolf
# 67
# the last dream of old oak
# 68
# the vain jackdaw
# 69
# the ant and the grasshopper
# 70
# the fox and the cock
# 71
# the fighting bulls and the frog
# 72
# shadows
# 73
# the eagle and the beetle
# 74
# the cat and the old rat
# 75
# on guard
# 76
# common people
# 77
# the striding place
# 78
# grumblegizzard
# 79
# the mother and the wolf
# 80
# how they ran away
# 81
# the heron
# 82
# the lion and the mouse
# 83
# going to the springs or vulgar people
# 84
# the old bachelors nightcap
# 85
# cupid and chow chow
# 86
# the lions share
# 87
# the bear and the bees
# 88
# the school girl
# 89
# the two pots
# 90
# street scenes in washington
# 91
# the fable of the preacher who flew his kite but not because he wished to do so
# 92
# the passing of peg leg
# 93
# following the fashions
# 94
# the dog in the manger
# 95
# the thorny road of honor
# 96
# andy lovell
# 97
# the man in the brown coat
# 98
# what the old man does is always right
# 99
# the dog the cock and the fox
# 100
# how the moon became beautiful
# 101
# the double trail
# 102
# the fox and the crab
# 103
# the miser
# 104
# the dogs and the hides
# 105
# the dog and his reflection
# 106
# making a sensation
# 107
# the little match girl
# 108
# the rat and the elephant
# 109
# the monkey and the dolphin
# 110
# the mice and the weasels
# 111
# the cat and the fox
# 112
# a college vagabond
# 113
# the eagle and the jackdaw
# 114
# dressed for a party
# 115
# roses and forget me nots
# 116
# the flying trunk
# 117
# the fox and the stork
# 118
# the attendants confession
# 119
# the fox and the crow
# 120
# a happy birthday
# 121
# coffee vs brandy
# 122
# the boys and the frogs
# 123
# the bundle of sticks
# 124
# the fox and the pheasants
# 125
# the man and the lion
# 126
# which was most the lady
# 127
# the fable of the man who didnt care for storybooks
# 128
# soup on a sausage peg
# 129
# little lizzie
# 130
# the lion the ass and the fox
# 131
# the old lion
# 132
# the leap at rhodes
# 133
# fear
# 134
# the frog and the mouse
# 135
# the mole and his mother
# 136
# the quack toad
# 137
# the seven that were hanged
# 138
# the hare and his ears
# 139
# the travelers and the purse
# 140
# elder tree mother
# 141
# the bat and the weasels
# 142
# the dog and his masters dinner
# 143
# the cock and the jewel
# 144
# rangering
# 145
# the fox and the goat
# 146
# the plane tree
# 147
# marjories three gifts
# 148
# something for a cold
# 149
# the ass and his purchaser
# 150
# visiting as neighbors
# 151
# a christmas dream and how it came to be true
# 152
# the naughty boy
# 153
# the fortune teller
# 154
# other peoples eyes
# 155
# the tinder box
# 156
# beauty of form and beauty of mind
# 157
# the little mermaid
# 158
# the wolf and the crane
# 159
# the peacock
# 160
# the shepherd boy and the wolf
# 161
# the travelers and the sea
# 162
# the wolf and the lamb
# 163
# the two goats
# 164
# the north wind and the sun
# 165
# the little angel
# 166
# the monkey and the camel
# 167
# the tortoise and the ducks
# 168
# brothers
# 169
# the wild boar and the fox
# 170
# the wicked prince
# 171
# the old house
# 172
# life
# 173
# the wolf in sheeps clothing
# 174
# at comanche ford
# 175
# the shadow
# 176
# a country christmas
# 177
# the piggy girl
# 178
# the ants and the grasshopper
# 179
# the oxen and the wheels
# 180
# the shoes of fortune
# 181
# the other woman
# 182
# the peacock and the crane
# 183
# the dance on the hill
# 184
# the ass and the load of salt
# 185
# the bell in the fog
# 186
# the fighting cocks and the eagle
# 187
# the princess and the pea
# 188
# the man and the satyr
# 189
# unlighted lamps
# 190
# the wolf and the sheep
# 191
# very poor
# 192
# a winter round up
# 193
# the fir tree and the bramble
# 194
# the skipping shoes
# 195
# love faith and hope
# 196
# lazarus
# 197
# the ugly duckling
# 198
# the two husbands
# 199
# the impostor
# 200
# the serpent and the eagle
# 201
# the owl and the grasshopper
# 202
# a little tiny thing
# 203
# miss mehetabels son
# 204
# the elderbush
# 205
# the vain jackdaw and his borrowed feathers
# 206
# my red cap
# 207
# its none of my business
# 208
# a rivermouth romance
# 209
# hadnt time for trouble
# 210
# the shepherd and the wolf
# 211
# a mystery explained
# 212
# ole luk oie the dream god
# 213
# round the yule log christmas in norway
# 214
# peace on earth good will to dogs
# 215
# little claus and big claus
# 216
# the oak and the reeds
# 217
# the fable of the kid who shifted his ideal
# 218
# a story which will never be finished
# 219
# the wolf and the shepherd
# 220
# the garden of paradise
# 221
# the tortoise and the hare
# 222
# the stag and the lion
# 223
# the ass the fox and the lion
# 224
# jupiter and the monkey
# 225
# the lion and the ass 2nd fable
# 226
# aunt kipp
# 227
# an angel in disguise
# 228
# around the spade wagon
# 229
# psyches art
# 230
# what the bell saw and said
# 231
# a visit with the doctor
# 232
# the swallow and the crow
# 233
# debbys debut
# 234
# the sheep and the pig
# 235
# the wolf and the lion
# 236
# the ass carrying the image
# 237
# marjorie daw
# 238
# the dog and the oyster
# 239
# the door of the trap
# 240
# under the willow tree
# 241
# the money box
# 242
# the fable of the parents who tinkered with the offspring
# 243
# the saucy boy
# 244
# seeds
# 245
# the fox and the leopard
# 246
# a modern cinderella
# 247
# the stag and his reflection
# 248
# the new englander
# 249
# the gnat and the bull
# 250
# the bat the bramble and the seagull
# 251
# the town mouse and the country mouse
# 252
# the snow queen
# 253
# the fox and the grapes
# 254
# the frogs and the ox
# 255
# the false collar
# 256
# the dumb man
# 257
# the animals and the plague
# 258
# the mischievous dog
# 259
# the sacrificial alter
# 260
# the real princess
# 261
# bad medicine
# 262
# the wolves and the sheep
# 263
# war
# 264
# the death of john
# 265
# rosys journey
# 266
# the mothers promise
# 267
# the cat the cock and the young mouse
# 268
# the indiscreet letter
# 269
# the serpents story
# 270
# the wild swans
# 271
# the fisherman and the little fish
# 272
# alice and the pigeon
# 273
# cousin tribulations story
# 274
# an old fashioned thanksgiving
# 275
# slow and sure
# 276
# the winds tale
# 277
# the thankless office
# 278
# the happy family
# 279
# the fox and the monkey
# 280
# romance and reality
# 281
# the astrologer
# 282
# the bull and the goat
# 283
# death and the woman
# 284
# hands
# 285
# the wolf and the ass
# 286
# a good name
# 287
# the bees and wasps and the hornet
# 288
# the wolf and the house dog
# 289
# the cross on the old church tower
# 290
# the wolf and the lean dog
# 291
# the story of a mother
# 292
# the miller his son and the ass 2
# 293
# the sun
# 294
# the wolf and the shepherd 2nd fable
# 295
# the cock and the fox
# 296
# where was wych street
# 297
# aunt marys suggestion
# 298
# the wolf and his shadow
# 299
# the goatherd and the goat
# 300
# the kid and the wolf
# 301
# the nightingale
# 302
# the shirt collar
# 303
# the egg
# 304
# hercules and the wagoner
# 305
# the old lion and the fox
# 306
# the mouse and the weasel
# 307
# the ass in the lions skin
# 308
# the wolf and the horse
# 309
# the red shoes
# 310
# the ass and the lap dog
# 311
# goody two shoes
# 312
# motherhood
# 313
# i want to know why
# 314
# the fir tree
# 315
# the frogs who wished for a king
# 316
# the flies and the honey
# 317
# an awakening
# 318
# the humbled pharisee
# 319
# the legend of babouscka
# 320
# the father and his sons
# 321
# seigermans per cent
# 322
# a hole in the wall
# 323
# the trees and the axe
# 324
# the fox without a tail
# 325
# the young crab and his mother
# 326
# the lion the bear and the fox
# 327
# the hares and the frogs
# 328
# the incubus
# 329
# the fox and the lion
# 330
# both to blame
# 331
# the snow man
# 332
# the goatherd and the wild goats
# 333
# on the day of the crucifixion
# 334
# the married sisters
# 335
# unredeemed pledges
# 336
# scarlet stockings
# 337
# the lion and the ass
# 338
# a source of irritation
# 339
# the dogs and the fox
# 340
# in the hands of his friends
# 341
# the ransom of don ramon mora
# 342
# the mule
# 343
# on picket duty
# 344
# three bullocks and a lion
# 345
# the farmer and his sons
# 346
# the red laugh
# 347
# the king of clubs and the queen of hearts
# 348
# the porcupine and the snakes
# 349
# the story of the wind
# 350
# the spendthrift and the swallow
# 351
# the brothers
# 352
# the story of a poker steer
# 353
# the night after christmas
# 354
# an act of piety
# 355
# the fatal error
# 356
# the boy bathing
# 357
# the fable of the two mandolin players and his willing performer
# 358
# louisa may alcott a childs biography
# 359
# what can i do
# 360
# the vain jackdaw 2
# 361
# the grasshopper and the ant
# 362
# the sick stag
# 363
# in the way of temptation
# 364
# dont mention it
# 365
# the portrait
# 366
# the dream of little tuk
# 367
# the shepherd and the lion
# 368
# the rose and the butterfly
# 369
# the cock and the fox 2nd fable
# 370
# the milkmaid and her pail
# 371
# the wolf and the kid
# 372
# the goose and the golden egg
# 373
# the monkey and the cat
# 374
# nellys hospital
# 375
